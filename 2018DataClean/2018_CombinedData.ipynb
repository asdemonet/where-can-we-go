# %%
# Read in Pandas

import pandas as pd

# %%
# Read in Cleaned Quarterly CSVs to Dataframes

Q12018_df = pd.read_csv('CleanQuarterCSVs/Combined2018Q1')
Q22018_df = pd.read_csv('CleanQuarterCSVs/Combined2018Q2')
Q32018_df = pd.read_csv('CleanQuarterCSVs/Combined2018Q3')
Q42018_df = pd.read_csv('CleanQuarterCSVs/Combined2018Q4')

# %%
# Created 2018 Dataframe. Use .append() to add each quarter

YR2018_df = Q12018_df.append(Q22018_df).append(Q32018_df).append(Q42018_df)

# Display data for the year of 2018

YR2018_df
# Out:
#             ITIN_ID  COUPONS  YEAR  ORIGIN_AIRPORT_ID  QUARTER ORIGIN  \
# 0         201814103        2  2018              14492        1    RDU
# 1         201814104        2  2018              14492        1    RDU
# 2         201814105        2  2018              14492        1    RDU
# 3         201814106        2  2018              14492        1    RDU
# 4         201814107        2  2018              14492        1    RDU
# ...             ...      ...   ...                ...      ...    ...
# 29807  201845683914        2  2018              14492        4    RDU
# 29808  201845683915        2  2018              14492        4    RDU
# 29809  201845683916        2  2018              14492        4    RDU
# 29810  201845683917        2  2018              14492        4    RDU
# 29811  201845683918        2  2018              14492        4    RDU
#
#        DEST_AIRPORT_ID DEST TICKET_CARRIER OPERATING_CARRIER  \
# 0                10423  AUS             DL                9E
# ...

# %%
YR2018_df.to_csv('YR2018_Final_CSV/YR2018Data.csv',index=False)
