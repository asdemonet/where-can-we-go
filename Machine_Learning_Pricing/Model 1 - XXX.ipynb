# %%
import pandas as pd

# %%
data_2015to2019 = pd.read_csv('../Resources/FINAL_MERGE_df.csv')

# %%
data_2015to2019.head()
# Out:
#      ITIN_ID  COUPONS  YEAR  ORIGIN_AIRPORT_ID  QUARTER ORIGIN  \
# 0  201917768        2  2019              14492        1    RDU
# 1  201917769        2  2019              14492        1    RDU
# 2  201917770        2  2019              14492        1    RDU
# 3  201917771        2  2019              14492        1    RDU
# 4  201917772        2  2019              14492        1    RDU
#
#    DEST_AIRPORT_ID DEST TICKET_CARRIER OPERATING_CARRIER REPORTING_CARRIER  \
# 0            10529  BDL             DL                9E                9E
# 1            10529  BDL             DL                9E                9E
# 2            10529  BDL             DL                9E                9E
# 3            10529  BDL             DL                9E                9E
# 4            10529  BDL             DL                9E                9E
#
#    PASSENGERS FARE_CLASS  DISTANCE_GROUP  ITIN_GEO_TYPE  ROUNDTRIP  ITIN_FARE  \
# ...
