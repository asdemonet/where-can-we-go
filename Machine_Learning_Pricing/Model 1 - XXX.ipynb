# %%
import pandas as pd

# %%
data_2015 = pd.read_csv('../Resources/rdu_2016_data_AD.csv')
data_2016 = pd.read_csv('../Resources/rdu_2016_data_AD.csv')
data_2017 = pd.read_csv('../Resources/YR2017Data.csv')
data_2018 = pd.read_csv('../Resources/YR2018Data.csv')
data_2019 = pd.read_csv('../Resources/MERGE_2019_df.csv')

# %%
data_2015 = data_2015.drop('Unnamed: 0',axis=1)
data_2015.head()
# Out:
#      ITIN_ID  COUPONS  YEAR  QUARTER ORIGIN  DEST_AIRPORT_ID DEST  \
# 0  201613434        2  2016        1    RDU            10529  BDL
# 1  201613435        2  2016        1    RDU            10529  BDL
# 2  201613436        2  2016        1    RDU            10529  BDL
# 3  201613437        2  2016        1    RDU            10529  BDL
# 4  201613438        2  2016        1    RDU            10529  BDL
#
#   TICKET_CARRIER OPERATING_CARRIER REPORTING_CARRIER  PASSENGERS FARE_CLASS  \
# 0             DL                9E                9E         1.0          X
# 1             DL                9E                9E         1.0          X
# 2             DL                9E                9E         1.0          X
# 3             DL                9E                9E         1.0          X
# 4             DL                9E                9E         5.0          X
#
#    DISTANCE_GROUP  ITIN_GEO_TYPE  ROUNDTRIP  ITIN_FARE  MILES_FLOWN
# ...

# %%
data_2016 = data_2016.drop('Unnamed: 0',axis=1)
data_2016.head()
# Out:
#      ITIN_ID  COUPONS  YEAR  QUARTER ORIGIN  DEST_AIRPORT_ID DEST  \
# 0  201613434        2  2016        1    RDU            10529  BDL
# 1  201613435        2  2016        1    RDU            10529  BDL
# 2  201613436        2  2016        1    RDU            10529  BDL
# 3  201613437        2  2016        1    RDU            10529  BDL
# 4  201613438        2  2016        1    RDU            10529  BDL
#
#   TICKET_CARRIER OPERATING_CARRIER REPORTING_CARRIER  PASSENGERS FARE_CLASS  \
# 0             DL                9E                9E         1.0          X
# 1             DL                9E                9E         1.0          X
# 2             DL                9E                9E         1.0          X
# 3             DL                9E                9E         1.0          X
# 4             DL                9E                9E         5.0          X
#
#    DISTANCE_GROUP  ITIN_GEO_TYPE  ROUNDTRIP  ITIN_FARE  MILES_FLOWN
# ...

# %%
data_2017.head()
# Out:
#      ITIN_ID  COUPONS  YEAR  ORIGIN_AIRPORT_ID  QUARTER ORIGIN  \
# 0  201712244        2  2017              14492        1    RDU
# 1  201712245        2  2017              14492        1    RDU
# 2  201712246        2  2017              14492        1    RDU
# 3  201712247        2  2017              14492        1    RDU
# 4  201712248        2  2017              14492        1    RDU
#
#    DEST_AIRPORT_ID DEST TICKET_CARRIER OPERATING_CARRIER REPORTING_CARRIER  \
# 0            10423  AUS             DL                9E                9E
# 1            10423  AUS             DL                9E                9E
# 2            10423  AUS             DL                9E                9E
# 3            10423  AUS             DL                9E                9E
# 4            10423  AUS             DL                9E                9E
#
#    PASSENGERS FARE_CLASS  DISTANCE_GROUP  ITIN_GEO_TYPE  ROUNDTRIP  ITIN_FARE  \
# ...

# %%
data_2018.head()
# Out:
#      ITIN_ID  COUPONS  YEAR  ORIGIN_AIRPORT_ID  QUARTER ORIGIN  \
# 0  201814103        2  2018              14492        1    RDU
# 1  201814104        2  2018              14492        1    RDU
# 2  201814105        2  2018              14492        1    RDU
# 3  201814106        2  2018              14492        1    RDU
# 4  201814107        2  2018              14492        1    RDU
#
#    DEST_AIRPORT_ID DEST TICKET_CARRIER OPERATING_CARRIER REPORTING_CARRIER  \
# 0            10423  AUS             DL                9E                9E
# 1            10423  AUS             DL                9E                9E
# 2            10423  AUS             DL                9E                9E
# 3            10423  AUS             DL                9E                9E
# 4            10423  AUS             DL                9E                9E
#
#    PASSENGERS FARE_CLASS  DISTANCE_GROUP  ITIN_GEO_TYPE  ROUNDTRIP  ITIN_FARE  \
# ...

# %%
data_2019.head()
# Out:
#      ITIN_ID  COUPONS  YEAR  ORIGIN_AIRPORT_ID  QUARTER ORIGIN  \
# 0  201917768        2  2019              14492        1    RDU
# 1  201917769        2  2019              14492        1    RDU
# 2  201917770        2  2019              14492        1    RDU
# 3  201917771        2  2019              14492        1    RDU
# 4  201917772        2  2019              14492        1    RDU
#
#    DEST_AIRPORT_ID DEST TICKET_CARRIER OPERATING_CARRIER REPORTING_CARRIER  \
# 0            10529  BDL             DL                9E                9E
# 1            10529  BDL             DL                9E                9E
# 2            10529  BDL             DL                9E                9E
# 3            10529  BDL             DL                9E                9E
# 4            10529  BDL             DL                9E                9E
#
#    PASSENGERS FARE_CLASS  DISTANCE_GROUP  ITIN_GEO_TYPE  ROUNDTRIP  ITIN_FARE  \
# ...
