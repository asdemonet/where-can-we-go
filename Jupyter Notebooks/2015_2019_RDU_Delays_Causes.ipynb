# %%
import pandas as pd
import numpy as np

# %%
RDU_2015_df = pd.read_csv('RDU_2015.csv')
RDU_2016_df = pd.read_csv('RDU_2016.csv')
RDU_2017_df = pd.read_csv('RDU_2017.csv')
RDU_2018_df = pd.read_csv('RDU_2018.csv')
RDU_2019_df = pd.read_csv('RDU_2019.csv')

# %%
RDU_2015_19_df = RDU_2015_df.append(RDU_2016_df)
RDU_2015_19_df = RDU_2015_19_df.append(RDU_2017_df)
RDU_2015_19_df = RDU_2015_19_df.append(RDU_2018_df)
RDU_2015_19_df = RDU_2015_19_df.append(RDU_2019_df)

# %%
RDU_2015_19_df
# Out:
#        Unnamed: 0  YEAR  QUARTER  MONTH  DAY_OF_MONTH  DAY_OF_WEEK  \
# 0             790  2015        1      1             1            4
# 1             791  2015        1      1             2            5
# 2             792  2015        1      1             3            6
# 3             793  2015        1      1             4            7
# 4             794  2015        1      1             5            1
# ...           ...   ...      ...    ...           ...          ...
# 64151      621780  2019        4     12            26            4
# 64152      621781  2019        4     12            26            4
# 64153      621782  2019        4     12            26            4
# 64154      621783  2019        4     12            26            4
# 64155      621784  2019        4     12            26            4
#
#           FL_DATE OP_UNIQUE_CARRIER TAIL_NUM  OP_CARRIER_FL_NUM  ...  \
# 0      2015-01-01                AA   N598AA               1302  ...
# ...

# %%
# Deleted following attributes: Tail Number, OriginCityName, OriginState, TaxiOut, WheelsOff, WheelsOn, TaxiIn, FirstDepTime, TotalAddGTime, LongestAddGtime.
RDU_2015_19_df = RDU_2015_19_df[['YEAR', 'QUARTER', 'MONTH', 'DAY_OF_MONTH', 'DAY_OF_WEEK','FL_DATE', 'OP_UNIQUE_CARRIER', 'OP_CARRIER_FL_NUM', 'ORIGIN_AIRPORT_ID', 'ORIGIN',
'ORIGIN_WAC', 'DEST_AIRPORT_ID', 'DEST', 'DEST_CITY_NAME','DEST_STATE_ABR', 'DEST_WAC', 'CRS_DEP_TIME', 'DEP_TIME', 'DEP_DELAY',
'DEP_DELAY_NEW', 'DEP_DEL15', 'DEP_DELAY_GROUP', 'DEP_TIME_BLK', 'CRS_ARR_TIME','ARR_TIME', 'ARR_DELAY', 'ARR_DELAY_NEW', 'ARR_DEL15','ARR_DELAY_GROUP', 'ARR_TIME_BLK', 'CANCELLED', 'CANCELLATION_CODE',
'DIVERTED', 'CRS_ELAPSED_TIME', 'ACTUAL_ELAPSED_TIME', 'AIR_TIME','DISTANCE', 'DISTANCE_GROUP', 'CARRIER_DELAY', 'WEATHER_DELAY','NAS_DELAY', 'SECURITY_DELAY', 'LATE_AIRCRAFT_DELAY']]

# %%
RDU_2015_19_df
# Out:
#        YEAR  QUARTER  MONTH  DAY_OF_MONTH  DAY_OF_WEEK     FL_DATE  \
# 0      2015        1      1             1            4  2015-01-01
# 1      2015        1      1             2            5  2015-01-02
# 2      2015        1      1             3            6  2015-01-03
# 3      2015        1      1             4            7  2015-01-04
# 4      2015        1      1             5            1  2015-01-05
# ...     ...      ...    ...           ...          ...         ...
# 64151  2019        4     12            26            4  2019-12-26
# 64152  2019        4     12            26            4  2019-12-26
# 64153  2019        4     12            26            4  2019-12-26
# 64154  2019        4     12            26            4  2019-12-26
# 64155  2019        4     12            26            4  2019-12-26
#
#       OP_UNIQUE_CARRIER  OP_CARRIER_FL_NUM  ORIGIN_AIRPORT_ID ORIGIN  ...  \
# 0                    AA               1302              14492    RDU  ...
# ...

# %%
list(RDU_2015_19_df.columns.values)
# Out:
# ['YEAR',
#  'QUARTER',
#  'MONTH',
#  'DAY_OF_MONTH',
#  'DAY_OF_WEEK',
#  'FL_DATE',
#  'OP_UNIQUE_CARRIER',
#  'OP_CARRIER_FL_NUM',
#  'ORIGIN_AIRPORT_ID',
#  'ORIGIN',
#  'ORIGIN_WAC',
#  'DEST_AIRPORT_ID',
#  'DEST',
#  'DEST_CITY_NAME',
#  'DEST_STATE_ABR',
#  'DEST_WAC',
#  'CRS_DEP_TIME',
#  'DEP_TIME',
#  'DEP_DELAY',
#  'DEP_DELAY_NEW',
#  'DEP_DEL15',
#  'DEP_DELAY_GROUP',
#  'DEP_TIME_BLK',
#  'CRS_ARR_TIME',
#  'ARR_TIME',
#  'ARR_DELAY',
#  'ARR_DELAY_NEW',
#  'ARR_DEL15',
#  'ARR_DELAY_GROUP',
#  'ARR_TIME_BLK',
#  'CANCELLED',
#  'CANCELLATION_CODE',
#  'DIVERTED',
#  'CRS_ELAPSED_TIME',
#  'ACTUAL_ELAPSED_TIME',
#  'AIR_TIME',
#  'DISTANCE',
#  'DISTANCE_GROUP',
#  'CARRIER_DELAY',
#  'WEATHER_DELAY',
#  'NAS_DELAY',
#  'SECURITY_DELAY',
#  'LATE_AIRCRAFT_DELAY']

# %%
RDU_2015_19_df.dtypes
# Out:
# YEAR                     int64
# QUARTER                  int64
# MONTH                    int64
# DAY_OF_MONTH             int64
# DAY_OF_WEEK              int64
# FL_DATE                 object
# OP_UNIQUE_CARRIER       object
# OP_CARRIER_FL_NUM        int64
# ORIGIN_AIRPORT_ID        int64
# ORIGIN                  object
# ORIGIN_WAC               int64
# DEST_AIRPORT_ID          int64
# DEST                    object
# DEST_CITY_NAME          object
# DEST_STATE_ABR          object
# DEST_WAC                 int64
# CRS_DEP_TIME             int64
# DEP_TIME               float64
# DEP_DELAY              float64
# DEP_DELAY_NEW          float64
# DEP_DEL15              float64
# DEP_DELAY_GROUP        float64
# DEP_TIME_BLK            object
# CRS_ARR_TIME             int64
# ARR_TIME               float64
# ARR_DELAY              float64
# ARR_DELAY_NEW          float64
# ARR_DEL15              float64
# ARR_DELAY_GROUP        float64
# ARR_TIME_BLK            object
# ...

# %%
RDU_2015_19_df.to_csv('RDU_2015_19_Delays_Causes_ML.csv')

# %%
MDW_2015_19_df = RDU_2015_19_df.loc[(RDU_2015_19_df["DEST"] == "MDW") & (RDU_2015_19_df["YEAR"] == 2015) & (RDU_2015_19_df["QUARTER"] == 1), :]

# %%
MDW_2015_19_df.to_csv('MDW_2015_Delays_Causes_TEST.csv')
